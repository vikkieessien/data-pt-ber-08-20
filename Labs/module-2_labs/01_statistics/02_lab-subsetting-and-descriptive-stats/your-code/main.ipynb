# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
#We have obect and float values
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
df_NYC = temp.loc[temp['State']== 'New York']
df_NYC
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %%
# Another way of doing it
df_NYC = temp[(temp['State'] == 'New York')]
df_NYC
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
df_NYC.mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here

Greater_15 = temp[(temp['Temperature'] > 15)]
Greater_15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
# Cities that has more than 15 degrees Celcius
Greater_15['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('Employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset (Years and Salary, 20 buckets). In few words describe these histograms?

# %%
# your answer here
employee.hist(bins = 20)
plt.show()

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
avg_salary = employee['Salary'].mean()
avg_salary
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
highest_salary = employee['Salary'].max()
highest_salary
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
lowest_salary = employee['Salary'].min()
lowest_salary
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
low_salaries_employee = employee[['Name', 'Salary']].min()
low_salaries_employee
# Out:
# Name      Ana
# Salary     30
# dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
David_info = employee.loc[employee['Name']== 'David']
David_info
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
David_Salary = David_info[['Name','Salary']]
David_Salary
# Out:
#     Name  Salary
# 2  David      30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
Title_associate = employee.loc[employee['Title']== 'associate']
Title_associate
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
#First method
first_method = employee.head(3)
first_method
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
# Second method
Second_method = employee.loc[:2]
Second_method
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
 
Ass_employee_with_salary_50 = employee[(employee['Title'] == 'associate') & 
                                       (employee['Salary']> 55)]
Ass_employee_with_salary_50
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %%
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
no_experience = employee.groupby(['Name','Years'])['Salary'].mean()
no_experience
# Out:
# Name    Years
# Ana     8        70
# Carlos  8        70
# David   2        30
# Eva     2        55
# Jose    1        35
# Maria   2        30
# Pedro   7        60
# Samuel  3        55
# Sonia   4        35
# Name: Salary, dtype: int64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
avg_salary = employee.groupby(['Title'])['Salary'].mean()
avg_salary
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
#seek for clarification
employee.boxplot()
# Out:
# <AxesSubplot:>

# %%
# print first quartile here
#the 25th percentile
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
#the 75th percentile
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
# Yes, the mean salary per gender is slightly different
mean_salary = employee.groupby(['Gender'])['Salary'].mean()
mean_salary
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
num_cols = employee.groupby(['Department']).agg(['min','max', 'mean']).reset_index()
num_cols
# Out:
#   Department Years               Salary
#                min max      mean    min max   mean
# 0         HR     2   8  4.666667     30  70  45.00
# 1         IT     1   8  4.500000     30  70  48.75
# 2      Sales     2   3  2.500000     55  55  55.00

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
# Diference between the maximal salary and minimal salary (max - min)
salary_diff =

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
pur_price = orders['amount_spent'].mean()
pur_price
# Out:
# 22.394748504739596

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
highest_price = orders['amount_spent'].max()
highest_price
# Out:
# 168469.6

# %%
# your answer here
low_price = orders['amount_spent'].min()
low_price
# Out:
# 0.0

# %%
#lowest amount _spent, top 3
orders.nsmallest(3, 'amount_spent')
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914         9302     537197     22841  2010     12    7    14
# 22539       33576     539263     22580  2010     12    4    14
# 25379       40089     539722     22423  2010     12    2    13
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 6914   round cake tin vintage green         1  2010-12-05 14:02:00        0.0
# 22539  advent calendar gingham sack         4  2010-12-16 14:36:00        0.0
# 25379      regency cakestand 3 tier        10  2010-12-21 13:45:00        0.0
#
#        CustomerID         Country  amount_spent
# 6914        12647         Germany           0.0
# 22539       16560  United Kingdom           0.0
# 25379       14911            EIRE           0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# Customers that are in Spain
#Spain_cus = orders[(orders['Country'] == 'Spain')]
#Spain_cus.head()

Spain_cus = orders.loc[orders['Country'] == 'Spain'] [['CustomerID', 'Country']].reset_index()
Spain_cus
# Out:
#        index  CustomerID Country
# 0       4250       12557   Spain
# 1       4251       12557   Spain
# 2       4252       12557   Spain
# 3       4253       12557   Spain
# 4       4254       12557   Spain
# ...      ...         ...     ...
# 2480  394733       17097   Spain
# 2481  394734       17097   Spain
# 2482  394735       17097   Spain
# 2483  394736       17097   Spain
# 2484  394737       17097   Spain
#
# [2485 rows x 3 columns]

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
Total_Spain_Cus = orders['Country'].value_counts()
Total_Spain_Cus
# Out:
# United Kingdom          354345
# Germany                   9042
# France                    8342
# EIRE                      7238
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1842
# Portugal                  1462
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# ...

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
cus_above_50 = orders[(orders['Quantity'] > 50)]
cus_above_50
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 397720      541702     581566     23404  2011     12    5    11
# 397721      541703     581567     21417  2011     12    5    11
# 397729      541711     581567     21326  2011     12    5    11
# 397761      541746     581571     23167  2011     12    5    12
# 397882      541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46         paper chain kit 50's christmas         80  2010-12-01 09:00:00
# ...

# %%
customers_50 = orders.loc[orders['Quantity'] > 50] [['CustomerID', 'Quantity']]
customers_50
# Out:
#         CustomerID  Quantity
# 46           13748        80
# 83           15291        64
# 96           14688       120
# 102          14688        96
# 174          16029       100
# ...            ...       ...
# 397720       18102       144
# 397721       16626        84
# 397729       16626       144
# 397761       15311        96
# 397882       13777        72
#
# [11609 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
Spain_orders = orders.loc[orders['Country'] == 'Spain'] > 50
Spain_orders
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-290-cb6cbe5925c1> in <module>
#       1 # your answer here
# ----> 2 Spain_orders = orders.loc[orders['Country'] == 'Spain'] > 50
#       3 Spain_orders
#
# ~\anaconda3\envs\kittycat\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#     702
#     703         # See GH#4537 for discussion of scalar op behavior
# --> 704         new_data = dispatch_to_series(self, other, op, axis=axis)
#     705         return self._construct_result(new_data)
#     706
#
# ~\anaconda3\envs\kittycat\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, axis)
#     263     if not is_list_like(right):
#     264         # i.e. scalar, faster than checking np.ndim(right) == 0
# --> 265         bm = left._mgr.apply(array_op, right=right)
#     266         return type(left)(bm)
#     267
#
# ...

# %%
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Select all free orders

# %%
# Free orders
Free_orders = orders[(orders['amount_spent'] == 0)]
Free_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here orders.loc[orders['Country'] == 'Spain'] [['CustomerID', 'Country']].reset_index()
Lunchbag_orders = orders.loc[orders['Description'] == 'Lunch bag'].reset_index()
Lunchbag_orders
# Out:
# Empty DataFrame
# Columns: [index, Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
