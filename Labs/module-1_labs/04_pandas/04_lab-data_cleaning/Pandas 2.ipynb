# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('vehicles.csv')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
# to see all the columns
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %% [raw]
# # to rename columns or column
# # implace means, the dataset will maintain its index, not rearranging the index.
# df.rename(columns={'Make':'Manufacture'}, inplace = True)
# df

# %%
df.values
# Out:
# array([['AM General', 'DJ Po Vehicle 2WD', 1984, ..., 17,
#         522.7647058823529, 1950],
#        ['AM General', 'FJ8c Post Office', 1984, ..., 13,
#         683.6153846153846, 2550],
#        ['AM General', 'Post Office DJ5 2WD', 1985, ..., 16, 555.4375,
#         2100],
#        ...,
#        ['smart', 'fortwo coupe', 2015, ..., 36, 244.0, 1100],
#        ['smart', 'fortwo coupe', 2016, ..., 36, 246.0, 1100],
#        ['smart', 'fortwo coupe', 2016, ..., 35, 255.0, 1150]],
#       dtype=object)

# %%
#renaming of columns 
df.rename(columns={'Make':'Manufacture', 'Engine Displacement': 'Displacement'}, inplace = True)
df.head()
# Out:
#         Manufacture                Model  Year  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1        AM General     FJ8c Post Office  1984           4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4  ASC Incorporated                  GNX  1987           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# ### Filtering Data ###

# %%
# That means filtering data where Manufacture equals Ford
df[df['Manufacture'] == 'Ford']
# Out:
#       Manufacture               Model  Year  Displacement  Cylinders  \
# 11440        Ford        Aerostar Van  1986           2.3        4.0
# 11441        Ford        Aerostar Van  1986           2.3        4.0
# 11442        Ford        Aerostar Van  1986           2.8        6.0
# 11443        Ford        Aerostar Van  1986           2.8        6.0
# 11444        Ford        Aerostar Van  1986           3.0        6.0
# ...           ...                 ...   ...           ...        ...
# 14381        Ford  Windstar FWD Wagon  2000           3.0        6.0
# 14382        Ford  Windstar FWD Wagon  2000           3.8        6.0
# 14383        Ford  Windstar FWD Wagon  2001           3.8        6.0
# 14384        Ford  Windstar FWD Wagon  2002           3.8        6.0
# 14385        Ford  Windstar FWD Wagon  2003           3.8        6.0
#
#           Transmission         Drivetrain  Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd   Rear-Wheel Drive           Vans   Regular
# ...

# %%
# Giving it a new variable
df[df['Manufacture'] == 'Ford']
df
# Out:
#             Manufacture                Model  Year  Displacement  Cylinders  \
# 0            AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1            AM General     FJ8c Post Office  1984           4.2        6.0
# 2            AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3            AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4      ASC Incorporated                  GNX  1987           3.8        6.0
# ...                 ...                  ...   ...           ...        ...
# 35947             smart         fortwo coupe  2013           1.0        3.0
# 35948             smart         fortwo coupe  2014           1.0        3.0
# 35949             smart         fortwo coupe  2015           1.0        3.0
# 35950             smart         fortwo coupe  2016           0.9        3.0
# 35951             smart         fortwo coupe  2016           0.9        3.0
#
# ...

# %%
df_ford = df[df['Manufacture'] == 'Ford']
df_ford.head()
# Out:
#       Manufacture         Model  Year  Displacement  Cylinders  \
# 11440        Ford  Aerostar Van  1986           2.3        4.0
# 11441        Ford  Aerostar Van  1986           2.3        4.0
# 11442        Ford  Aerostar Van  1986           2.8        6.0
# 11443        Ford  Aerostar Van  1986           2.8        6.0
# 11444        Ford  Aerostar Van  1986           3.0        6.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11441     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11442  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11443     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11444     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11440          17.347895        18           22            19
# 11441          13.733750        23           26            24
# ...

# %%
# to create a new dataframe that is more specific
# the two statement has to be in seperate parenthesis and the two statement have to be in one bracket

# df_ford = df[df['Manufacture'] == 'Ford']
df_ford_1986 = df[(df['Manufacture'] == 'Ford') & (df['Year'] == 1986)]
df_ford_1986
# Out:
#       Manufacture         Model  Year  Displacement  Cylinders  \
# 11440        Ford  Aerostar Van  1986           2.3        4.0
# 11441        Ford  Aerostar Van  1986           2.3        4.0
# 11442        Ford  Aerostar Van  1986           2.8        6.0
# 11443        Ford  Aerostar Van  1986           2.8        6.0
# 11444        Ford  Aerostar Van  1986           3.0        6.0
# ...           ...           ...   ...           ...        ...
# 14270        Ford   Thunderbird  1986           2.3        4.0
# 14271        Ford   Thunderbird  1986           2.3        4.0
# 14272        Ford   Thunderbird  1986           3.8        6.0
# 14273        Ford   Thunderbird  1986           3.8        6.0
# 14274        Ford   Thunderbird  1986           5.0        8.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11441     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# ...

# %%
df_ford_1986.head()
# Out:
#       Manufacture         Model  Year  Displacement  Cylinders  \
# 11440        Ford  Aerostar Van  1986           2.3        4.0
# 11441        Ford  Aerostar Van  1986           2.3        4.0
# 11442        Ford  Aerostar Van  1986           2.8        6.0
# 11443        Ford  Aerostar Van  1986           2.8        6.0
# 11444        Ford  Aerostar Van  1986           3.0        6.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11441     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11442  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11443     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11444     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11440          17.347895        18           22            19
# 11441          13.733750        23           26            24
# ...

# %%
df.describe()
# Out:
#               Year  Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000  35952.000000  35952.000000       35952.000000
# mean    2000.71640      3.338493      5.765076          17.609056
# std       10.08529      1.359395      1.755268           4.467283
# min     1984.00000      0.600000      2.000000           0.060000
# 25%     1991.00000      2.200000      4.000000          14.699423
# 50%     2001.00000      3.000000      6.000000          17.347895
# 75%     2010.00000      4.300000      6.000000          20.600625
# max     2017.00000      8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# ...

# %%
# creating of new column with aggregate
df['Age'] = 2020 - df['Year']
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#    Fuel Barrels/Year  City MPG  Combined MPG  CO2 Emission Grams/Mile  \
# ...

# %%
df['2020']= df['Age'] + df['Year']
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#    Fuel Barrels/Year  City MPG  Combined MPG  CO2 Emission Grams/Mile  \
# ...

# %% [markdown]
# ### Applying functions to columns ###

# %%
df.sum(axis=1)
# Out:
# 0        6573.653529
# 1        7335.170000
# 2        6754.538125
# 3        7335.170000
# 4        7205.838125
#             ...
# 35947    5467.155833
# 35948    5466.155833
# 35949    5467.155833
# 35950    5469.055833
# 35951    5525.317429
# Length: 35952, dtype: float64

# %%
# Dropping Two columns
df = df.drop(['Highway MPG', 'Fuel Type'], axis = 1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-663b75e6ec99> in <module>
#       1 # Dropping Two columns
# ----> 2 df = df.drop(['Highway MPG', 'Fuel Type'], axis = 1)
#       3 df
#
# ~\anaconda3\envs\kittycat\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4158                 weight  1.0     0.8
#    4159         """
# -> 4160         return super().drop(
#    4161             labels=labels,
#    4162             axis=axis,
#
# ~\anaconda3\envs\kittycat\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
df['2020'] = df['Age'] - df['Year']
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#    Fuel Barrels/Year  City MPG  Combined MPG  CO2 Emission Grams/Mile  \
# ...

# %%
# '‘’ Let’s say we want to take a sum of all numeric columns in the animals DataFrame. We can do this by
#using the sum function and passing axis=1 as an argument to the function. ‘’'
yes= df.sum(axis=1)
yes.head()
# Out:
# 0    2605.653529
# 1    3367.170000
# 2    2784.538125
# 3    3365.170000
# 4    3231.838125
# dtype: float64

# %%
#sum of rows

# %%
row = df.sum(axis=0)
row
# Out:
# Make                       AM GeneralAM GeneralAM GeneralAM GeneralASC In...
# Model                      DJ Po Vehicle 2WDFJ8c Post OfficePost Office D...
# Year                                                                71929756
# Engine Displacement                                                   120026
# Cylinders                                                             207266
# Transmission               Automatic 3-spdAutomatic 3-spdAutomatic 3-spdA...
# Drivetrain                 2-Wheel Drive2-Wheel DriveRear-Wheel DriveRear...
# Vehicle Class              Special Purpose Vehicle 2WDSpecial Purpose Veh...
# Fuel Barrels/Year                                                     633081
# City MPG                                                              634414
# Combined MPG                                                          716499
# CO2 Emission Grams/Mile                                          1.70886e+07
# ...

# %%
#calling out columns, subset

# %%
df[['Year', 'City MPG']]
# Out:
#        Year  City MPG
# 0      1984        18
# 1      1984        13
# 2      1985        16
# 3      1985        13
# 4      1987        14
# ...     ...       ...
# 35947  2013        34
# 35948  2014        34
# 35949  2015        34
# 35950  2016        34
# 35951  2016        32
#
# [35952 rows x 2 columns]

# %%
# sorting columns by ascending or descending     if you want asc then  u. have to assign Ascending = True
df.sort_values(by = 'Year', inplace =True, ascending = True)
df = df.sort_values(by =  'Year')
df.head()
# Out:
#              Make              Model  Year  Engine Displacement  Cylinders  \
# 0      AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 26753      Nissan         Pickup 2WD  1984                  2.4        4.0
# 26752      Nissan         Pickup 2WD  1984                  2.0        4.0
# 31002      Subaru           Brat 4WD  1984                  1.8        4.0
# 31003      Subaru           Brat 4WD  1984                  1.8        4.0
#
#           Transmission                  Drivetrain  \
# 0      Automatic 3-spd               2-Wheel Drive
# 26753  Automatic 3-spd               2-Wheel Drive
# 26752     Manual 5-spd               2-Wheel Drive
# 31002  Automatic 3-spd  4-Wheel or All-Wheel Drive
# 31003     Manual 4-spd  4-Wheel or All-Wheel Drive
#
#                      Vehicle Class  Fuel Barrels/Year  City MPG  Combined MPG  \
# 0      Special Purpose Vehicle 2WD          19.388824        18            17
# ...

# %%
#getting the largest number from a column (top 5 or whatever)
df.nlargest(5, 'Year')
# Out:
#       Make              Model  Year  Engine Displacement  Cylinders  \
# 2635   BMW        M240i Coupe  2017                  3.0        6.0
# 2634   BMW        M240i Coupe  2017                  3.0        6.0
# 2633   BMW  M240i Convertible  2017                  3.0        6.0
# 20721  Kia        Sorento FWD  2017                  2.4        4.0
# 20722  Kia        Sorento FWD  2017                  3.3        6.0
#
#          Transmission         Drivetrain                    Vehicle Class  \
# 2635     Manual 6-spd   Rear-Wheel Drive                  Subcompact Cars
# 2634   Automatic (S8)   Rear-Wheel Drive                  Subcompact Cars
# 2633     Manual 6-spd   Rear-Wheel Drive                  Subcompact Cars
# 20721  Automatic (S6)  Front-Wheel Drive  Small Sport Utility Vehicle 2WD
# 20722  Automatic (S6)  Front-Wheel Drive  Small Sport Utility Vehicle 2WD
#
#        Fuel Barrels/Year  City MPG  Combined MPG  CO2 Emission Grams/Mile  \
# ...

# %%
#getting the largest value from more than one column
df.nlargest(3,['Year','City MPG', 'Combined MPG'])
# Out:
#          Make          Model  Year  Engine Displacement  Cylinders  \
# 33280  Toyota      Prius Eco  2017                  1.8        4.0
# 33278  Toyota          Prius  2017                  1.8        4.0
# 17058   Honda  Accord Hybrid  2017                  2.0        4.0
#
#                            Transmission         Drivetrain Vehicle Class  \
# 33280  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
# 33278  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
# 17058  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
#
#        Fuel Barrels/Year  City MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 33280           5.885893        58            56                    158.0
# 33278           6.338654        54            52                    171.0
# 17058           6.866875        49            48                    183.0
#
#        Fuel Cost/Year  Age  2020
# 33280             600    3 -2014
# 33278             650    3 -2014
# ...

# %%
#getting the smallest value from columns
df.nsmallest(3,['Year','City MPG', 'Combined MPG'])
# Out:
#         Make                Model  Year  Engine Displacement  Cylinders  \
# 9068   Dodge       B350 Wagon 2WD  1984                  5.9        8.0
# 11807   Ford  E150 Club Wagon 2WD  1984                  5.8        8.0
# 11936   Ford   E250 Econoline 2WD  1984                  5.8        8.0
#
#           Transmission     Drivetrain         Vehicle Class  \
# 9068   Automatic 3-spd  2-Wheel Drive  Vans, Passenger Type
# 11807  Automatic 3-spd  2-Wheel Drive  Vans, Passenger Type
# 11936  Automatic 3-spd  2-Wheel Drive      Vans, Cargo Type
#
#        Fuel Barrels/Year  City MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 9068           36.623333         8             9               987.444444
# 11807          36.623333         9             9               987.444444
# 11936          36.623333         9             9               987.444444
#
#        Fuel Cost/Year  Age  2020
# 9068             3700   36 -1948
# 11807            3700   36 -1948
# ...

# %%
#getting the mean of the dataframe
df.mean()
# Out:
# Year                       2000.716400
# Engine Displacement           3.338493
# Cylinders                     5.765076
# Fuel Barrels/Year            17.609056
# City MPG                     17.646139
# Combined MPG                 19.929322
# CO2 Emission Grams/Mile     475.316339
# Fuel Cost/Year             1892.598465
# Age                          19.283600
# 2020                      -1981.432799
# dtype: float64

# %%
# to get the upper letters for columns, you have to str before upper
df['Make'].str.upper()
df['Make'].apply(str.upper)
# Out:
# 0           AM GENERAL
# 26753           NISSAN
# 26752           NISSAN
# 31002           SUBARU
# 31003           SUBARU
#              ...
# 24109    MERCEDES-BENZ
# 851               AUDI
# 24108    MERCEDES-BENZ
# 14410              GMC
# 20450              KIA
# Name: Make, Length: 35952, dtype: object

# %%
#using lambda to turn values in column to upper case
df['Make'].apply(lambda x : x.upper())
# Out:
# 0           AM GENERAL
# 26753           NISSAN
# 26752           NISSAN
# 31002           SUBARU
# 31003           SUBARU
#              ...
# 24109    MERCEDES-BENZ
# 851               AUDI
# 24108    MERCEDES-BENZ
# 14410              GMC
# 20450              KIA
# Name: Make, Length: 35952, dtype: object

# %%
df['Make'].apply(lambda x: x.replace('a', 'b'))
# Out:
# 0           AM Generbl
# 26753           Nissbn
# 26752           Nissbn
# 31002           Subbru
# 31003           Subbru
#              ...
# 24109    Mercedes-Benz
# 851               Audi
# 24108    Mercedes-Benz
# 14410              GMC
# 20450              Kib
# Name: Make, Length: 35952, dtype: object

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Barrels/Year',
#        'City MPG', 'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year',
#        'Age', '2020'],
#       dtype='object')

# %%
df.groupby(['Year']).mean().reset_index().head()
# Out:
#    Year  Engine Displacement  Cylinders  Fuel Barrels/Year   City MPG  \
# 0  1984             3.927752   6.102326          21.185192  15.485271
# 1  1985             3.170462   5.388362          18.090052  17.872233
# 2  1986             3.184764   5.430976          18.201528  17.675926
# 3  1987             3.138815   5.384808          18.373926  17.414858
# 4  1988             3.201698   5.469169          18.311235  17.321716
#
#    Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year   Age    2020
# 0     16.844961               570.355997     2125.891473  36.0 -1948.0
# 1     19.805187               487.234897     1840.101202  35.0 -1950.0
# 2     19.562290               490.418652     1859.343434  34.0 -1952.0
# 3     19.349750               495.114201     1881.886477  33.0 -1954.0
# 4     19.315460               493.516114     1885.701519  32.0 -1956.0

# %%
df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# count  35952.000000  35952.000000             35952.000000    35952.000000
# mean      17.646139     19.929322               475.316339     1892.598465
# std        4.769349      5.112409               119.060773      506.958627
# ...

# %%
# grouping by Make and suming Engine displacement, age and Fuel Cost/year
df.groupby(['Make'])['Engine Displacement', 'Age', 'Fuel Cost/Year'].sum().reset_index()
# Out:
# <ipython-input-47-6a17a0394adf>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Make'])['Engine Displacement', 'Age', 'Fuel Cost/Year'].sum().reset_index()
#                             Make  Engine Displacement    Age  Fuel Cost/Year
# 0                     AM General                 13.4    142            9150
# 1               ASC Incorporated                  3.8     33            2550
# 2                          Acura                856.1   4985          559450
# 3                     Alfa Romeo                104.8   1153           80450
# 4    American Motors Corporation                 83.9    779           41650
# ..                           ...                  ...    ...             ...
# 122                   Volkswagen               2341.1  17874         1653650
# 123                        Volvo               1795.9  12775         1299400
# ...

# %%
df.groupby(['Make', 'Model', 'Combined MPG'])['Engine Displacement', 'Fuel Barrels/Year'].median().reset_index()
# Out:
# <ipython-input-48-571f70231099>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Make', 'Model', 'Combined MPG'])['Engine Displacement', 'Fuel Barrels/Year'].median().reset_index()
#                   Make                Model  Combined MPG  \
# 0           AM General    DJ Po Vehicle 2WD            17
# 1           AM General     FJ8c Post Office            13
# 2           AM General  Post Office DJ5 2WD            16
# 3           AM General  Post Office DJ8 2WD            13
# 4     ASC Incorporated                  GNX            16
# ...                ...                  ...           ...
# 9676             smart     fortwo cabriolet            35
# 9677             smart     fortwo cabriolet            36
# 9678             smart   fortwo convertible            36
# 9679             smart         fortwo coupe            35
# ...

# %%
df.groupby(['Make'])['Engine Displacement', 'Combined MPG'].agg(['mean', 'median','sum', 'std']).reset_index()
# Out:
# <ipython-input-49-4d620e598800>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Make'])['Engine Displacement', 'Combined MPG'].agg(['mean', 'median','sum', 'std']).reset_index()
#                             Make Engine Displacement                           \
#                                                 mean median     sum       std
# 0                     AM General            3.350000   3.35    13.4  0.981495
# 1               ASC Incorporated            3.800000   3.80     3.8       NaN
# 2                          Acura            2.834768   3.00   856.1  0.672588
# 3                     Alfa Romeo            2.556098   2.50   104.8  0.568792
# 4    American Motors Corporation            3.813636   4.20    83.9  0.729184
# ..                           ...                 ...    ...     ...       ...
# 122                   Volkswagen            2.236008   2.00  2341.1  0.599835
# ...

# %%
#using and or or as conditional statement
filtered = df[(df['Make']=='Ford') &
                (df['Cylinders']>=6) &
                (df['Combined MPG'] < 18)]
filtered
# Out:
#        Make                        Model  Year  Engine Displacement  \
# 13775  Ford            Ranger Pickup 2WD  1984                  2.8
# 13134  Ford              F250 Pickup 4WD  1984                  5.8
# 13132  Ford              F250 Pickup 4WD  1984                  5.0
# 13133  Ford              F250 Pickup 4WD  1984                  5.8
# 13934  Ford            Ranger Pickup 4WD  1984                  2.8
# ...     ...                          ...   ...                  ...
# 14048  Ford         Shelby GT350 Mustang  2017                  5.2
# 14352  Ford           Transit T150 Wagon  2017                  3.5
# 13695  Ford          Mustang Convertible  2017                  5.0
# 14355  Ford       Transit T150 Wagon FFV  2017                  3.7
# 13698  Ford  Mustang Performance Package  2017                  5.0
#
#        Cylinders     Transmission                  Drivetrain  \
# 13775        6.0  Automatic 3-spd               2-Wheel Drive
# ...

# %%
# ou will also notice that in some cases Automatic is abbreviated to Auto and in other cases it is spelled out.
# We can make that more consistent by using the same technique. While we are at it, let’s also attempt to remove
# parentheses and make spacing more consistent.‘’'
# data[‘trany’] = data[‘trany’].str.replace(‘Automatic’, ‘Auto’)
# data[‘trany’] = data[‘trany’].str.replace(‘Auto\(’, ‘Auto ’)
# data[‘trany’] = data[‘trany’].str.replace(‘Manual\(’, ‘Manual ’)
# data[‘trany’] = data[‘trany’].str.replace(‘\(‘, ‘’)
# data[‘trany’] = data[‘trany’].str.replace(‘\)‘, ‘’)
# print(set(data[‘trany’]))

# %%
# to get numeric columns from a dataframe ._get_numeric_data()
df._get_numeric_data()
# Out:
#        Year  Engine Displacement  Cylinders  Fuel Barrels/Year  City MPG  \
# 0      1984                  2.5        4.0          19.388824        18
# 26753  1984                  2.4        4.0          17.347895        18
# 26752  1984                  2.0        4.0          12.207778        24
# 31002  1984                  1.8        4.0          15.695714        20
# 31003  1984                  1.8        4.0          13.733750        22
# ...     ...                  ...        ...                ...       ...
# 24109  2017                  2.0        4.0          12.677308        23
# 851    2017                  2.0        4.0          12.207778        24
# 24108  2017                  2.0        4.0          12.677308        23
# 14410  2017                  3.6        6.0          19.388824        15
# 20450  2017                  1.6        4.0          13.184400        23
#
#        Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  Age  2020
# ...

# %%
df.select_dtypes(np.number).head()
# Out:
#        Year  Engine Displacement  Cylinders  Fuel Barrels/Year  City MPG  \
# 0      1984                  2.5        4.0          19.388824        18
# 26753  1984                  2.4        4.0          17.347895        18
# 26752  1984                  2.0        4.0          12.207778        24
# 31002  1984                  1.8        4.0          15.695714        20
# 31003  1984                  1.8        4.0          13.733750        22
#
#        Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  Age  2020
# 0                17               522.764706            1950   36 -1948
# 26753            19               467.736842            1750   36 -1948
# 26752            27               329.148148            1250   36 -1948
# 31002            21               423.190476            1600   36 -1948
# 31003            24               370.291667            1400   36 -1948

# %%
#getting the column's names that are numeric
df.select_dtypes(np.number).columns
# Out:
# Index(['Year', 'Engine Displacement', 'Cylinders', 'Fuel Barrels/Year',
#        'City MPG', 'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year',
#        'Age', '2020'],
#       dtype='object')

# %%
# to get float values in the dataframe
df.select_dtypes(float).head()
# Out:
#        Engine Displacement  Cylinders  Fuel Barrels/Year  \
# 0                      2.5        4.0          19.388824
# 26753                  2.4        4.0          17.347895
# 26752                  2.0        4.0          12.207778
# 31002                  1.8        4.0          15.695714
# 31003                  1.8        4.0          13.733750
#
#        CO2 Emission Grams/Mile
# 0                   522.764706
# 26753               467.736842
# 26752               329.148148
# 31002               423.190476
# 31003               370.291667

# %%
#when you want columns that has no number
df.select_dtypes(exclude=np.number).head()
# Out:
#              Make              Model     Transmission  \
# 0      AM General  DJ Po Vehicle 2WD  Automatic 3-spd
# 26753      Nissan         Pickup 2WD  Automatic 3-spd
# 26752      Nissan         Pickup 2WD     Manual 5-spd
# 31002      Subaru           Brat 4WD  Automatic 3-spd
# 31003      Subaru           Brat 4WD     Manual 4-spd
#
#                        Drivetrain                Vehicle Class
# 0                   2-Wheel Drive  Special Purpose Vehicle 2WD
# 26753               2-Wheel Drive      Small Pickup Trucks 2WD
# 26752               2-Wheel Drive      Small Pickup Trucks 2WD
# 31002  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD
# 31003  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD

# %% [markdown]
# ### Applying Functions to columns ###

# %%
df.sum()
# Out:
# Make                       AM GeneralNissanNissanSubaruSubaruFordFordFord...
# Model                      DJ Po Vehicle 2WDPickup 2WDPickup 2WDBrat 4WDB...
# Year                                                                71929756
# Engine Displacement                                                   120026
# Cylinders                                                             207266
# Transmission               Automatic 3-spdAutomatic 3-spdManual 5-spdAuto...
# Drivetrain                 2-Wheel Drive2-Wheel Drive2-Wheel Drive4-Wheel...
# Vehicle Class              Special Purpose Vehicle 2WDSmall Pickup Trucks...
# Fuel Barrels/Year                                                     633081
# City MPG                                                              634414
# Combined MPG                                                          716499
# CO2 Emission Grams/Mile                                          1.70886e+07
# ...

# %%
df.sum(axis = 1)
# Out:
# 0        6573.653529
# 1        7335.170000
# 2        6754.538125
# 3        7335.170000
# 4        7205.838125
#             ...
# 35947    5467.155833
# 35948    5466.155833
# 35949    5467.155833
# 35950    5469.055833
# 35951    5525.317429
# Length: 35952, dtype: float64

# %%
#getting the sum of year
df['Year'].sum()
# Out:
# 71929756

# %%
#sum of year and City MPG
df[['Year','City MPG']].sum()
# Out:
# Year        71929756
# City MPG      634414
# dtype: int64

# %%
#columns of the dataframe
df.columns
# Out:
# Index(['Manufacture', 'Model', 'Year', 'Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Barrels/Year',
#        'City MPG', 'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year',
#        'Age', '2020'],
#       dtype='object')

# %%
# when you want to select more tha one column, you need double square bracket
columns_to_compute = ['Year', 'City MPG']
df[columns_to_compute].sum()
# Out:
# Year        71929756
# City MPG      634414
# dtype: int64

# %%
# .upper() only works on one element, hence to apply to a column, you have to use 'apply', also you have to include str.upper()
df['Manufacture'].apply(str.upper)
# Out:
# 0              AM GENERAL
# 1              AM GENERAL
# 2              AM GENERAL
# 3              AM GENERAL
# 4        ASC INCORPORATED
#                ...
# 35947               SMART
# 35948               SMART
# 35949               SMART
# 35950               SMART
# 35951               SMART
# Name: Manufacture, Length: 35952, dtype: object

# %%
# 'to replace 'a' by 'b'
df['Manufacture'].apply(lambda x: x.replace('a', 'b'))
# Out:
# 0              AM Generbl
# 1              AM Generbl
# 2              AM Generbl
# 3              AM Generbl
# 4        ASC Incorporbted
#                ...
# 35947               smbrt
# 35948               smbrt
# 35949               smbrt
# 35950               smbrt
# 35951               smbrt
# Name: Manufacture, Length: 35952, dtype: object

# %%
df['Manufacture'].apply(lambda x: x.replace('/', ''))
# Out:
# 0              AM General
# 1              AM General
# 2              AM General
# 3              AM General
# 4        ASC Incorporated
#                ...
# 35947               smart
# 35948               smart
# 35949               smart
# 35950               smart
# 35951               smart
# Name: Manufacture, Length: 35952, dtype: object

# %%
df['Manufacture'].apply(lambda x: x.replace('m', 'w'))
# Out:
# 0              AM General
# 1              AM General
# 2              AM General
# 3              AM General
# 4        ASC Incorporated
#                ...
# 35947               swart
# 35948               swart
# 35949               swart
# 35950               swart
# 35951               swart
# Name: Manufacture, Length: 35952, dtype: object

# %% [markdown]
# ### Dataframe Aggregation using groupby ###

# %%
df.mean()
# Out:
# Year                       2000.716400
# Displacement                  3.338493
# Cylinders                     5.765076
# Fuel Barrels/Year            17.609056
# City MPG                     17.646139
# Combined MPG                 19.929322
# CO2 Emission Grams/Mile     475.316339
# Fuel Cost/Year             1892.598465
# Age                          19.283600
# 2020                       2020.000000
# dtype: float64

# %%
df.groupby(['Fuel Type']).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-ec06feaf2ffa> in <module>
# ----> 1 df.groupby(['Fuel Type']).mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5799         axis = self._get_axis_number(axis)
#    5800
# -> 5801         return groupby_generic.DataFrameGroupBy(
#    5802             obj=self,
#    5803             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
#     404                 obj,
#     405                 keys,
#
# ...

# %%
df.groupby(['Fuel Type']).max()

# %%
df.groupby(['Fuel Type']).min()

# %%
df.groupby(['Fuel Type'])['Cylinders','City MPG'].agg(['mean', 'sum', 'std', 'max'])

# %%
df.groupby(['Fuel Type'])['Cylinders', 'City MPG'].mean().reset_index()

# %%
# getting the largest number from a column
# pokemon.nlargest(5,'A/D Ratio')

# %% [markdown]
# ### importinh and examining the data ###

# %%
df = pd.read_csv('vehicles_messy.csv')
# Out:
# C:\Users\vicke\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
# ...

# %%
# what are some of the issues?
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %% [markdown]
# ### investigating and replacing null values ###

# %%
# the is null is checking any column that has no value and wherevere there is no value, it will give false and when is value, its a true
df.isnull()
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0          False       False      False      False   False    False    False
# 1          False       False      False      False   False    False    False
# 2          False       False      False      False   False    False    False
# 3          False       False      False      False   False    False    False
# 4          False       False      False      False   False    False    False
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838      False       False      False      False   False    False    False
# 37839      False       False      False      False   False    False    False
# 37840      False       False      False      False   False    False    False
# 37841      False       False      False      False   False    False    False
# 37842      False       False      False      False   False    False    False
#
# ...

# %%
pd.isnull(df)
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0          False       False      False      False   False    False    False
# 1          False       False      False      False   False    False    False
# 2          False       False      False      False   False    False    False
# 3          False       False      False      False   False    False    False
# 4          False       False      False      False   False    False    False
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838      False       False      False      False   False    False    False
# 37839      False       False      False      False   False    False    False
# 37840      False       False      False      False   False    False    False
# 37841      False       False      False      False   False    False    False
# 37842      False       False      False      False   False    False    False
#
# ...

# %%
# to know how many has no values
df.isnull().sum(axis=0)
# Out:
# barrels08         0
# barrelsA08        0
# charge120         0
# charge240         0
# city08            0
#               ...
# modifiedOn        0
# startStop     31705
# phevCity          0
# phevHwy           0
# phevComb          0
# Length: 83, dtype: int64

# %%
# to make the 31705 be converted to % like other data set
df.isnull().sum() / len(df)
# Out:
# barrels08     0.000000
# barrelsA08    0.000000
# charge120     0.000000
# charge240     0.000000
# city08        0.000000
#                 ...
# modifiedOn    0.000000
# startStop     0.837804
# phevCity      0.000000
# phevHwy       0.000000
# phevComb      0.000000
# Length: 83, dtype: float64

# %%
# to find out only columns that has null values and also has above zero, the numbers there identifies the totoal number of values
null_cols = df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
# to check for any column that has no missing value zeor means no missing values
df.isnull().sum()==0
# Out:
# barrels08      True
# barrelsA08     True
# charge120      True
# charge240      True
# city08         True
#               ...
# modifiedOn     True
# startStop     False
# phevCity       True
# phevHwy        True
# phevComb       True
# Length: 83, dtype: bool

# %%
# to check for all the non missing values only
df.isnull().sum()
# Out:
# barrels08         0
# barrelsA08        0
# charge120         0
# charge240         0
# city08            0
#               ...
# modifiedOn        0
# startStop     31705
# phevCity          0
# phevHwy           0
# phevComb          0
# Length: 83, dtype: int64

# %%
# all the columns with names that has missing values
null_cols = df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
# the columns that has over certain number of missing values
null_cols[null_cols > 10000]
# Out:
# eng_dscr      15403
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
df.drop(null_cols[null_cols > 10000])
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838  14.982273         0.0        0.0        0.0      19      0.0        0
# 37839  14.330870         0.0        0.0        0.0      20      0.0        0
# 37840  15.695714         0.0        0.0        0.0      18      0.0        0
# 37841  15.695714         0.0        0.0        0.0      18      0.0        0
# 37842  18.311667         0.0        0.0        0.0      16      0.0        0
#
# ...

# %%
# we have discovered that a particular column has too much missing value and its crack, we can decide to drop it
df.drop(['evMotor','mfrCode'], axis=1)
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838  14.982273         0.0        0.0        0.0      19      0.0        0
# 37839  14.330870         0.0        0.0        0.0      20      0.0        0
# 37840  15.695714         0.0        0.0        0.0      18      0.0        0
# 37841  15.695714         0.0        0.0        0.0      18      0.0        0
# 37842  18.311667         0.0        0.0        0.0      16      0.0        0
#
# ...

# %%
# to drop all the columns under here null_cols[null_cols > 10000]
null_cols[null_cols > 10000].index
# Out:
# Index(['eng_dscr', 'guzzler', 'trans_dscr', 'tCharger', 'sCharger', 'atvType',
#        'fuelType2', 'rangeA', 'evMotor', 'mfrCode', 'c240Dscr', 'c240bDscr',
#        'startStop'],
#       dtype='object')

# %%
# dropping columns of more than 1000 missing values
# drop_cols =list([null_cols > 10000].index)
# data =data.drop(drop_cols, axis=1)
cols_missing_values = list(null_cols[null_cols > 10000].index)
cols_missing_values
df = df.drop(cols_missing_values, axis=1)
df
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838  14.982273         0.0        0.0        0.0      19      0.0        0
# 37839  14.330870         0.0        0.0        0.0      20      0.0        0
# 37840  15.695714         0.0        0.0        0.0      18      0.0        0
# 37841  15.695714         0.0        0.0        0.0      18      0.0        0
# 37842  18.311667         0.0        0.0        0.0      16      0.0        0
#
# ...

# %%
# drop_values

# %%
# replacing the missing values

# %%
# to check how many missing values in cylinders column
sum(df['cylinders'].isnull())
# Out:
# 0

# %%
# replacing the cylinders column with 0
df['cylinders'].fillna(0)
# Out:
# 0         4.0
# 1        12.0
# 2         4.0
# 3         8.0
# 4         4.0
#          ...
# 37838     4.0
# 37839     4.0
# 37840     4.0
# 37841     4.0
# 37842     4.0
# Name: cylinders, Length: 37843, dtype: float64

# %%
df['cylinders'] = df['cylinders'].fillna(0)

# %%
# checking if there are any missing values in cylinders after filling it
sum(df['cylinders'].isnull())
# Out:
# 0

# %% [markdown]
# ### Cleaning Text ###

# %%
# when you want to have a distinct value
# the result below displays an unclean data with so many reptition and different spellings
set(df['trany'])
# Out:
# {'Auto (AV)',
#  'Auto (AVS6)',
#  'Auto (AVS8)',
#  'Auto(A1)',
#  'Auto(AM5)',
#  'Auto(AM6)',
#  'Auto(AM7)',
#  'Auto(AM8)',
#  'Auto(AMS6)',
#  'Auto(AMS7)',
#  'Auto(AMS8)',
#  'Auto(AMS9)',
#  'Auto(AVS6)',
#  'Auto(AVS7)',
#  'Auto(AVS8)',
#  'Auto(L3)',
#  'Auto(L4)',
#  'Automatic (A1)',
#  'Automatic (A6)',
#  'Automatic (AM5)',
#  'Automatic (AM6)',
#  'Automatic (AV)',
#  'Automatic (AVS6)',
#  'Automatic (S4)',
#  'Automatic (S5)',
#  'Automatic (S6)',
#  'Automatic (S7)',
#  'Automatic (S8)',
#  'Automatic (S9)',
#  'Automatic (variable gear ratios)',
#  'Automatic 3spd',
#  'Automatic 4spd',
#  'Automatic 5spd',
#  'Automatic 6spd',
#  'Automatic 7spd',
#  'Automatic 8spd',
#  'Automatic 9spd',
#  'Manual 3spd',
#  'Manual 4spd',
#  'Manual 4spd Doubled',
#  'Manual 5 spd',
#  'Manual 5spd',
#  'Manual 6spd',
#  'Manual 7spd',
#  'Manual(M7)',
#  nan}

# %%
# repace the dashes with empty space
# df['trany'] = df['trany'].str.replace('-', '')
# df['trany'] = df['trany'].str.replace('Automatic' 'Auto')
# set(['trany'])

# %%
df['trany'] = df['trany'].str.replace("-", "")

# %%
set(df['trany'])
# Out:
# {'Auto (AV)',
#  'Auto (AVS6)',
#  'Auto (AVS8)',
#  'Auto(A1)',
#  'Auto(AM5)',
#  'Auto(AM6)',
#  'Auto(AM7)',
#  'Auto(AM8)',
#  'Auto(AMS6)',
#  'Auto(AMS7)',
#  'Auto(AMS8)',
#  'Auto(AMS9)',
#  'Auto(AVS6)',
#  'Auto(AVS7)',
#  'Auto(AVS8)',
#  'Auto(L3)',
#  'Auto(L4)',
#  'Automatic (A1)',
#  'Automatic (A6)',
#  'Automatic (AM5)',
#  'Automatic (AM6)',
#  'Automatic (AV)',
#  'Automatic (AVS6)',
#  'Automatic (S4)',
#  'Automatic (S5)',
#  'Automatic (S6)',
#  'Automatic (S7)',
#  'Automatic (S8)',
#  'Automatic (S9)',
#  'Automatic (variable gear ratios)',
#  'Automatic 3spd',
#  'Automatic 4spd',
#  'Automatic 5spd',
#  'Automatic 6spd',
#  'Automatic 7spd',
#  'Automatic 8spd',
#  'Automatic 9spd',
#  'Manual 3spd',
#  'Manual 4spd',
#  'Manual 4spd Doubled',
#  'Manual 5 spd',
#  'Manual 5spd',
#  'Manual 6spd',
#  'Manual 7spd',
#  'Manual(M7)',
#  nan}

# %%
df[‘trany’] = df[‘trany’].str.replace(“Automatic”, “Auto”).str.replace(” “, “”).str.replace(‘\)’,“”)
set(df[‘trany’])
# Out:
#   File "<ipython-input-170-0cd88ba780af>", line 1
#     df[‘trany’] = df[‘trany’].str.replace(“Automatic”, “Auto”).str.replace(” “, “”).str.replace(‘\)’,“”)
#              ^
# SyntaxError: invalid character in identifier

# %% [markdown]
# ### Dropping duplicates ###

# %%
# it drops all the duplicated data
df.drop_duplicates()
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838  14.982273         0.0        0.0        0.0      19      0.0        0
# 37839  14.330870         0.0        0.0        0.0      20      0.0        0
# 37840  15.695714         0.0        0.0        0.0      18      0.0        0
# 37841  15.695714         0.0        0.0        0.0      18      0.0        0
# 37842  18.311667         0.0        0.0        0.0      16      0.0        0
#
# ...

# %%
# droping it on a specific columns. You can drop duplicates after cleaning the data
df[['year', 'cylinders', 'trany']].drop_duplicates()
# Out:
#        year  cylinders                             trany
# 0      1985        4.0                       Manual 5spd
# 1      1985       12.0                       Manual 5spd
# 3      1985        8.0                    Automatic 3spd
# 4      1993        4.0                       Manual 5spd
# 5      1993        4.0                    Automatic 3spd
# ...     ...        ...                               ...
# 37469  1993        6.0                    Automatic (S4)
# 37471  1993        4.0                       Manual 6spd
# 37513  1993       12.0                       Manual 6spd
# 37567  1993        8.0                    Automatic (S5)
# 37683  1993        3.0  Automatic (variable gear ratios)
#
# [1349 rows x 3 columns]

# %%
# pd.merge(a, b, left_on =, right_on =)

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how: str = 'inner', on=None, left_on=None, right_on=None, left_index: bool = False, right_index: bool = False, sort: bool = False, suffixes=('_x', '_y'), copy: bool = True, indicator: bool = False, validate=None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %%
# pd.merge(a, b, left_on=“IndexCol”, right_on = “IndexCol”, how = “right”)
# a.merge(b, on=“IndexCol”, how = “right”)

# %%
# pd.merge(a, b, left_on=“IndexCol”, right_on = “IndexCol”, how = “right”)
# a.merge(b, on=“IndexCol”, how = “right”)
